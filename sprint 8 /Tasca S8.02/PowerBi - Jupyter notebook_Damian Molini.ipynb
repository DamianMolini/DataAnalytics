# %% [markdown]
# # Nivell 1

# %% [markdown]
# ## Exercici 1
# #### Una variable numèrica.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Para crear el primer gráfico, seleccioné los campos "amount" y "declined" de la tabla Transactions ya presente en Power BI. Lo que hice a continuación fue seleccionar de este dataset solo las transacciones donde "declined" sea igual a 0.
# #### Es importante mencionar que para que Power BI muestre el gráfico, siempre tiene que estar presente la línea "plt.show()". De lo contrario, dará un error ya que no reconoce ninguna imagen para mostrar.

# %% [markdown]
# ## Exercici 2
# #### Dues variables numèriques.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Para crear el gráfico de dispersión, seleccioné el campo "price" y una medida que ya tenía creada, "Count Products", que me permite contar la cantidad de ventas que tiene cada producto (solo teniendo en cuenta las transacciones no rechazadas). A continuación vemos la medida:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercici 3
# #### Una variable categòrica.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercici 4
# #### Una variable categòrica i una numèrica.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### En este caso, para el dataset necesité el amount, country y declined, ya que solo nos interesaban las ventas efectivas. El código es casi idéntico al original, excepto por el "tight_layout" que necesité para que la figura se vea correctamente.

# %% [markdown]
# ## Exercici 5
# #### Dues variables categòriques.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### En este caso, utilicé los campos country, id y grupo de edad. Este último era un campo condicional que había creado en Power Query durante los anteriores sprints, pero que modifiqué para que los grupos sean iguales a los que había definido en Python (menos de 30, 30-40 y más de 40).
#
# #### He cambiado el contexto a "talk" para que el gráfico pudiera verse correctamente, ya que de lo contrario el tamaño de la fuente era muy pequeño con respecto al gráfico.

# %% [markdown]
# ## Exercici 6
# #### Tres variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Para poder realizar este gráfico de líneas, creé el campo "año-mes" en la tabla de calendario dentro de Power BI. Para que la leyenda no se superponga con el gráfico, tuve que eliminar la leyenda creada automáticamente con el "hue" y luego crear la leyenda con la posición exacta mediante "plt.legend".
#
# #### Para el monto, utilizamos la siguiente medida:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercici 7
# #### Graficar un Pairplot.

# %% [markdown]
# #### En este caso, el código es casi igual al original, solo tuvimos que agregar "plt.tight_layout" para que el gráfico se ajuste a la página de Power BI. La medida "Count Products" utilizada en el dataset es la misma que en el ejercicio 2.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Para este ejercicio utilicé la misma medida de "Count Products" que en el ejercicio 2, donde visualizo la cantidad de ventas por productos, contando solo las transacciones no rechazadas.

# %% [markdown]
#  # NIVELL 2

# %% [markdown]
# ## Exercici 1
# #### Correlació de totes les variables numèriques.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### En este caso el código es igual al original de Python, y el dataset contiene las columnas númericas de las que queremos tomar la correlación. Además, configuramos el contexto a "talk" para que el tamño de la fuente sea más grande.

# %% [markdown]
# ## Exercici 2
# #### Implementa un jointplot.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Para este gráfico, tuvimos que cambiar el contexto a "talk" para que se pueda ver correctamente en Power BI. Además, rotamos las etiquetas del eje x para que no se superpongan.

# %% [markdown]
# # Nivell 3

# %% [markdown]
# ## Exercici 1
# #### Implementa un violinplot combinat amb un altre tipus de gràfic.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### En este caso, en primer lugar seleccionamos el contexto "poster" para que la imagen se vea correctamente.
# #### Luego, del dataset seleccionamos solo los países que nos interesan en este caso: Canadá, Australia, Países Bajos y Alemania.
# #### Al crear el violin plot, seleccionamos solo las transacciones que se hayan efectivizado (declined = 0)
# #### Por último, en el swarmplot agregamos el parámetro "Size" para que el tamaño de los marcadores sea más grande y se vea mejor.

# %% [markdown]
# ## Exercici 2
# #### Genera un FacetGrid per a visualitzar múltiples aspectes de les dades simultàniament.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### En el código original de Python, necesitamos agrupar para sumar las ventas "(data=df_productsSales_color.groupby(["country", "color", "price"])["sales"].sum().reset_index())". En el caso de Power BI, como ya contábamos con la medida "Count Products" mostrada en el ejercicio 2 del nivel 1, no hizo falta agrupar a la hora de seleccionar el dataset.
# #### Además, agregamos en Power BI el "row_order" para que las filas tengan el mismo orden que teníamos en Python.
#
# #### Por último, con el código "plt.subplots_adjust" reacomodamos el gráfico para darle espacio al título del gráfico en Power BI.
